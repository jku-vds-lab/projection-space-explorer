# %%
FILE_NAME = 'games'
import re

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(FILE_NAME) if isfile(join(FILE_NAME, f))]

# %%
print(onlyfiles)
# Out:
# ['game-00001.pgn', 'game-00002.pgn', 'game-00003.pgn', 'game-00004.pgn', 'game-00005.pgn', 'game-00006.pgn', 'game-00007.pgn', 'game-00008.pgn', 'game-00009.pgn', 'game-00010.pgn', 'game-00011.pgn', 'game-00012.pgn', 'game-00013.pgn', 'game-00014.pgn', 'game-00015.pgn', 'game-00016.pgn', 'game-00017.pgn', 'game-00018.pgn', 'game-00019.pgn', 'game-00020.pgn', 'game-00021.pgn', 'game-00022.pgn', 'game-00023.pgn', 'game-00024.pgn', 'game-00025.pgn', 'game-00026.pgn', 'game-00027.pgn', 'game-00028.pgn', 'game-00029.pgn', 'game-00030.pgn', 'game-00031.pgn', 'game-00032.pgn', 'game-00033.pgn', 'game-00034.pgn', 'game-00035.pgn', 'game-00036.pgn', 'game-00037.pgn', 'game-00038.pgn', 'game-00039.pgn', 'game-00040.pgn', 'game-00041.pgn', 'game-00042.pgn', 'game-00043.pgn', 'game-00044.pgn', 'game-00045.pgn', 'game-00046.pgn', 'game-00047.pgn', 'game-00048.pgn', 'game-00049.pgn', 'game-00050.pgn', 'game-00051.pgn', 'game-00052.pgn', 'game-00053.pgn', 'game-00054.pgn', 'game-00055.pgn', 'game-0
# ...

# %%
for path in onlyfiles:
    with open(FILE_NAME+'/'+path, "r") as f:
        s = f.read()
#         m = re.findall(r'{ \[%clk(.*?) (.*?)\] }',s)
#         print(m)
#         if len(m) != 0:
#             print('this is bad')
        if 'KOBE24LUIS' in s and 'Juanitochess' in s:
            print(path)
            print(s)
# Out:
# game-00783.pgn
# [Event "Rated Blitz tournament https://lichess.org/tournament/mg8GKo1o"]
# [Site "https://lichess.org/iVltd1ly"]
# [Date "2021.08.01"]
# [Round "-"]
# [White "KOBE24LUIS"]
# [Black "Juanitochess"]
# [Result "0-1"]
# [UTCDate "2021.08.01"]
# [UTCTime "00:10:11"]
# [WhiteElo "1704"]
# [BlackElo "2023"]
# [WhiteRatingDiff "-2"]
# [BlackRatingDiff "+2"]
# [BlackTitle "CM"]
# [ECO "B40"]
# [Opening "Sicilian Defense: French Variation"]
# [TimeControl "180+0"]
# [Termination "Time forfeit"]
#
# 1. e4 { [%eval 0.24] [%clk 0:03:00] } 1... c5 { [%eval 0.32] [%clk 0:01:30] } 2. Nf3 { [%eval 0.0] [%clk 0:02:56] } 2... e6?! { [%eval 0.54] [%clk 0:01:30] } 3. Bc4?! { [%eval 0.0] [%clk 0:02:56] } 3... d5 { [%eval 0.24] [%clk 0:01:29] } 4. d4?? { [%eval -3.93] [%clk 0:02:56] } 4... dxc4 { [%eval -5.52] [%clk 0:01:28] } 0-1

# %%
print(len([]))
# Out:
# 0
